# %%
import pandas as pd
dataset = pd.read_csv("Salary_Data.csv")

# %%
from matplotlib import pyplot as plt
plt.plot(dataset.YearsExperience,dataset.Salary,'darkb')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-30675367b0b5> in <module>
#       1 from matplotlib import pyplot as plt
# ----> 2 plt.plot(dataset.YearsExperience,dataset.Salary,'dark')
#
# c:\users\student\appdata\local\programs\python\python36\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
#    2748     return gca().plot(
# -> 2749         *args, scalex=scalex, scaley=scaley, data=data, **kwargs)
#    2750
#    2751 # Autogenerated by boilerplate.py.  Do not edit as changes will be lost.
#
# c:\users\student\appdata\local\programs\python\python36\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# c:\users\student\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1602         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1603
# -> 1604         for line in self._get_lines(*args, **kwargs):
#    1605             self.add_line(line)
#    1606             lines.append(line)
#
# c:\users\student\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# c:\users\student\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     340         ret = []
#     341         if len(tup) > 1 and isinstance(tup[-1], str):
# --> 342             linestyle, marker, color = _process_plot_format(tup[-1])
#     343             tup = tup[:-1]
#     344         elif len(tup) == 3:
#
# c:\users\student\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py in _process_plot_format(fmt)
#     116         else:
#     117             raise ValueError(
# --> 118                 'Unrecognized character %c in format string' % c)
#     119         i += 1
#     120
#
# ValueError: Unrecognized character a in format string

# %%
from pandas import ExcelWriter
from pandas import ExcelFile
dataset1 = pd.read_excel('wt_vs_ht.xlsx',sheetName='sheet2')

print(dataset1)
# Out:
#       61    48  F
# 0   62.0  56.0  F
# 1   65.0  62.0  M
# 2   60.0  52.0  F
# 3   70.0  74.0  M
# 4   71.0  64.4  M
# 5   71.0  65.0  M
# 6   71.5  64.0  M
# 7   71.0  66.0  M
# 8   71.0  80.0  M
# 9   67.0  68.0  M
# 10  68.0  76.0  M
# 11  64.5  53.0  F
# 12  63.0  56.0  M
# 13  70.0  72.0  M
# 14  69.0  80.0  M
# 15  66.0  68.0  M
# 16  68.0  70.0  M
# 17  72.0  69.0  M
# 18  72.0  65.0  M
# 19  72.0  72.0  M
# 20  69.0  55.0  M
# 21  67.0  52.0  M
# 22  63.0  65.0  M
# 23  72.0  61.0  M
# 24  68.0  85.0  M
# 25  69.0  63.0  M
# 26  70.0  65.0  M
# 27  66.0  68.0  M
# 28  70.0  56.0  M
# 29  71.0  65.0  M
